# %% [markdown]
# <a href="https://colab.research.google.com/github/its-0faraz/DSnote/blob/main/python_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#pandas is python data analysis

# %%
#dictionaries ku flower ma use krna
dict1 = {'India':'I love you', 'uk':10, 'us':True}
dict1
# Out:
# {'India': 'I love you', 'uk': 10, 'us': True}

# %%
stats = pd.read_csv('/content/DemographicData.csv')

# %%
stats.head()
#pehle 5 lina deta empty hai toh bracket ma 10 diye toh 10 dats aata
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    195 non-null    object
#  1   Country Code    195 non-null    object
#  2   Birth rate      195 non-null    float64
#  3   Internet users  195 non-null    float64
#  4   Income Group    195 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 7.7+ KB

# %%
stats.describe()
# Out:
#        Birth rate  Internet users
# count  195.000000      195.000000
# mean    21.469928       42.076471
# std     10.605467       29.030788
# min      7.900000        0.900000
# 25%     12.120500       14.520000
# 50%     19.680000       41.000000
# 75%     29.759500       66.225000
# max     49.661000       96.546800

# %%
stats.columns
#ye list hai isme () use ny krna
# Out:
# Index(['Country Name', 'Country Code', 'Birth rate', 'Internet users',
#        'Income Group'],
#       dtype='object')

# %%
stats.columns = ['CountryName', 'CountryCode', 'Birthrate', 'Internetusers',
       'IncomeGroup']

# %%
stats.columns
#plural ma use kar gaaf ma damm karra
# Out:
# Index(['CountryName', 'CountryCode', 'Birthrate', 'Internetusers',
#        'IncomeGroup'],
#       dtype='object')

# %%
stats[3:8]
# Out:
#             CountryName CountryCode  Birthrate  Internetusers  \
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
# 5             Argentina         ARG     17.716           59.9
# 6               Armenia         ARM     13.308           41.9
# 7   Antigua and Barbuda         ATG     16.447           63.4
#
#            IncomeGroup
# 3  Upper middle income
# 4          High income
# 5          High income
# 6  Lower middle income
# 7          High income

# %%
stats.columns[1:3]
# Out:
# Index(['CountryCode', 'Birthrate'], dtype='object')

# %%
stats.iloc[:,1:3].values
# Out:
# array([['ABW', 10.244],
#        ['AFG', 35.253],
#        ['AGO', 45.985],
#        ['ALB', 12.877],
#        ['ARE', 11.044],
#        ['ARG', 17.716],
#        ['ARM', 13.308],
#        ['ATG', 16.447],
#        ['AUS', 13.2],
#        ['AUT', 9.4],
#        ['AZE', 18.3],
#        ['BDI', 44.151],
#        ['BEL', 11.2],
#        ['BEN', 36.44],
#        ['BFA', 40.551],
#        ['BGD', 20.142],
#        ['BGR', 9.2],
#        ['BHR', 15.04],
#        ['BHS', 15.339],
#        ['BIH', 9.062],
#        ['BLR', 12.5],
#        ['BLZ', 23.092],
#        ['BMU', 10.4],
#        ['BOL', 24.236],
#        ['BRA', 14.931],
#        ['BRB', 12.188],
#        ['BRN', 16.405],
#        ['BTN', 18.134],
#        ['BWA', 25.267],
#        ['CAF', 34.076],
#        ['CAN', 10.9],
#        ['CHE', 10.2],
#        ['CHL', 13.385],
#        ['CHN', 12.1],
#        ['CIV', 37.32],
#        ['CMR', 37.236],
#        ['COG', 37.011],
#        ['COL', 16.076],
#        ['COM', 34.326],
# ...

# %%
stats.iloc[:2,3:]
# Out:
#    Internetusers  IncomeGroup
# 0           78.9  High income
# 1            5.9   Low income

# %%
stats.iloc[:2,3:].values
# Out:
# array([[78.9, 'High income'],
#        [5.9, 'Low income']], dtype=object)

# %%
stats.iloc[2:6:3,1:4:2]
# Out:
#   CountryCode  Internetusers
# 2         AGO           19.1
# 5         ARG           59.9

# %%
stats.iloc[[2,5],[1,3]]
# : is for is to yaha se vaha tak karo bolna
# Out:
#   CountryCode  Internetusers
# 2         AGO           19.1
# 5         ARG           59.9

# %%
stats.Internetusers/stats.Birthrate
# Out:
# 0      7.702070
# 1      0.167362
# 2      0.415353
# 3      4.442028
# 4      7.968127
#          ...
# 190    0.607036
# 191    2.230216
# 192    0.051894
# 193    0.380519
# 194    0.517990
# Length: 195, dtype: float64

# %%
stats['New'] = stats.Internetusers/stats.Birthrate

# %%
stats.head()
# Out:
#             CountryName CountryCode  Birthrate  Internetusers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup       New
# 0          High income  7.702070
# 1           Low income  0.167362
# 2  Upper middle income  0.415353
# 3  Upper middle income  4.442028
# 4          High income  7.968127

# %%
stats.drop("New",1)
#delete ny karta khali dikhata
# Out:
# <ipython-input-24-86678205a6e4>:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   stats.drop("New",1)
#               CountryName CountryCode  Birthrate  Internetusers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
# ...

# %%
stats.head()
# Out:
#             CountryName CountryCode  Birthrate  Internetusers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup       New
# 0          High income  7.702070
# 1           Low income  0.167362
# 2  Upper middle income  0.415353
# 3  Upper middle income  4.442028
# 4          High income  7.968127

# %%
stats = stats.drop("New",1)
# Out:
# <ipython-input-26-7341b2b77c41>:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   stats = stats.drop("New",1)

# %%
stats.head()
# Out:
#             CountryName CountryCode  Birthrate  Internetusers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
stats.Birthrate > 40
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4      False
#        ...
# 190    False
# 191    False
# 192     True
# 193     True
# 194    False
# Name: Birthrate, Length: 195, dtype: bool

# %%
stats[stats.Birthrate > 40]
# Out:
#           CountryName CountryCode  Birthrate  Internetusers  \
# 2              Angola         AGO     45.985           19.1
# 11            Burundi         BDI     44.151            1.3
# 14       Burkina Faso         BFA     40.551            9.1
# 65        Gambia, The         GMB     42.525           14.0
# 115              Mali         MLI     44.138            3.5
# 127             Niger         NER     49.661            1.7
# 128           Nigeria         NGA     40.045           38.0
# 156           Somalia         SOM     43.891            1.5
# 167              Chad         TCD     45.745            2.3
# 178            Uganda         UGA     43.474           16.2
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
#
#              IncomeGroup
# 2    Upper middle income
# 11            Low income
# 14            Low income
# 65            Low income
# 115           Low income
# 127           Low income
# ...

# %%
stats.Birthrate < 10
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 190    False
# 191    False
# 192    False
# 193    False
# 194    False
# Name: Birthrate, Length: 195, dtype: bool

# %%
stats[stats.Birthrate < 10]
# Out:
#                 CountryName CountryCode  Birthrate  Internetusers  \
# 9                   Austria         AUT      9.400        80.6188
# 16                 Bulgaria         BGR      9.200        53.0615
# 19   Bosnia and Herzegovina         BIH      9.062        57.7900
# 45                  Germany         DEU      8.500        84.1700
# 53                    Spain         ESP      9.100        71.6350
# 68                   Greece         GRC      8.500        59.8663
# 74     Hong Kong SAR, China         HKG      7.900        74.2000
# 76                  Croatia         HRV      9.400        66.7476
# 78                  Hungary         HUN      9.200        72.6439
# 86                    Italy         ITA      8.500        58.4593
# 89                    Japan         JPN      8.200        89.7100
# 95              Korea, Rep.         KOR      8.600        84.7700
# 102           Liechtenstein         LIE      9.200        93.8000
# ...

# %%
stats[(stats.Birthrate > 40) & (stats.Internetusers < 10)]
#practice
# Out:
#           CountryName CountryCode  Birthrate  Internetusers IncomeGroup
# 11            Burundi         BDI     44.151            1.3  Low income
# 14       Burkina Faso         BFA     40.551            9.1  Low income
# 115              Mali         MLI     44.138            3.5  Low income
# 127             Niger         NER     49.661            1.7  Low income
# 156           Somalia         SOM     43.891            1.5  Low income
# 167              Chad         TCD     45.745            2.3  Low income
# 192  Congo, Dem. Rep.         COD     42.394            2.2  Low income

# %%
stats[(stats.Birthrate < 50) & (stats.Internetusers < 10) & (stats.IncomeGroup != 'Low Income')]
# Out:
#                   CountryName CountryCode  Birthrate  Internetusers  \
# 1                 Afghanistan         AFG     35.253           5.90
# 11                    Burundi         BDI     44.151           1.30
# 13                      Benin         BEN     36.440           4.90
# 14               Burkina Faso         BFA     40.551           9.10
# 15                 Bangladesh         BGD     20.142           6.63
# 29   Central African Republic         CAF     34.076           3.50
# 34              Cote d'Ivoire         CIV     37.320           8.40
# 35                   Cameroon         CMR     37.236           6.40
# 36                Congo, Rep.         COG     37.011           6.60
# 38                    Comoros         COM     34.326           6.50
# 46                   Djibouti         DJI     25.486           9.50
# 52                    Eritrea         ERI     34.800           0.90
# 55                   Ethiopia         ETH     32.925           1.90
# ...

# %%
stats['IncomeGroup'].unique()
# Out:
# array(['High income', 'Low income', 'Upper middle income',
#        'Lower middle income'], dtype=object)

# %%
stats.iat[2,2]
# Out:
# 45.985

# %%
stats.at[2, 'Birthrate']
#jab tumreku sirf header name mlum rehta
# Out:
# 45.985

# %%
import seaborn as sns

# %%
sns.boxplot(data=stats, x='IncomeGroup', y='Birthrate')
# Out:
# <AxesSubplot:xlabel='IncomeGroup', ylabel='Birthrate'>

# %%
sns.boxplot(data=stats, x='IncomeGroup', y='Internetusers')
# Out:
# <AxesSubplot:xlabel='IncomeGroup', ylabel='Internetusers'>

# %%
sns.boxplot(data=stats, x='Internetusers', y='Birthrate')
# Out:
# <AxesSubplot:xlabel='Internetusers', ylabel='Birthrate'>

# %%
sns.lmplot(data=stats, x='Internetusers', y='Birthrate')

# %%
sns.lmplot(data=stats, x='Internetusers', y='Birthrate', hue = 'IncomeGroup')

# %%
sns.lmplot(data=stats, x='Internetusers', y='Birthrate', hue = 'IncomeGroup', fit_reg= False)

# %%
sns.lmplot(data=stats, x='Internetusers', y='Birthrate', hue = 'IncomeGroup', fit_reg= False, scatter_kws={'s':150})
#kws used to increse size
